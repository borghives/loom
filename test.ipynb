# %%
from loom.info import Persistable, declare_persist_db
from typing import Type
from loom.info.model import TimeInserted, TimeUpdated

@declare_persist_db(db_name="test", collection_name="test")
class TestUpdateModel(Persistable):
    model_id: ObjectId
    name: str
    value: int
    created_at: TimeInserted
    updated_time: TimeUpdated

# %%
from typing import Annotated
from bson.objectid import ObjectId
import rich
from typing import get_origin, get_args, Union

def get_base_type(annotation):
    """Recursively unwraps Annotated and Optional/Union types."""
    origin = get_origin(annotation)
    args = get_args(annotation)

    # Handle Annotated: Extract the first argument (the actual type)
    if origin is Annotated:
        return get_base_type(args[0])
    elif origin is Union:
        return get_base_type(args[0])

    return annotation

def is_objectid(annotation, field_type: Type):
    return get_base_type(annotation) is field_type

for key, field in TestUpdateModel.model_fields.items():
    annotation = field.annotation
    if is_objectid(annotation, ObjectId):
        print(f"{key} is an ObjectId field!")
# Out:
# id is an ObjectId field!
# model_id is an ObjectId field!

# %%
from bson import ObjectId
ObjectId('aaa')
# Out:
# ---------------------------------------------------------------------------
# InvalidId                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from bson import ObjectId
# ----> 2 ObjectId('aaa')
#
# File ~/projects/loom/.venv/lib/python3.12/site-packages/bson/objectid.py:105, in ObjectId.__init__(self, oid)
#     103     self.__id = oid
#     104 else:
# --> 105     self.__validate(oid)
#
# File ~/projects/loom/.venv/lib/python3.12/site-packages/bson/objectid.py:193, in ObjectId.__validate(self, oid)
#     191             _raise_invalid_id(oid)
#     192     else:
# --> 193         _raise_invalid_id(oid)
#     194 else:
#     195     raise TypeError(f"id must be an instance of (bytes, str, ObjectId), not {type(oid)}")
#
# File ~/projects/loom/.venv/lib/python3.12/site-packages/bson/objectid.py:38, in _raise_invalid_id(oid)
#      37 def _raise_invalid_id(oid: str) -> NoReturn:
# ---> 38     raise InvalidId(
#      39         "%r is not a valid ObjectId, it must be a 12-byte input"
#      40         " or a 24-character hex string" % oid
#      41     )
#
# InvalidId: 'aaa' is not a valid ObjectId, it must be a 12-byte input or a 24-character hex string
